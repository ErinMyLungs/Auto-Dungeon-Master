# %%
import PyPDF2
import glob
from pprint import pprint

# %%
prep_filepath = glob.glob('/home/erin/Documents/dnd/prepared*.pdf')[0]
prepared_pdf = open(prep_filepath, 'rb')

# %%
pdfReader = PyPDF2.PdfFileReader(prepared_pdf)

# %%
list(pdfReader.getPage(3).keys())
# Out:
# ['/ArtBox',
#  '/BleedBox',
#  '/Contents',
#  '/CropBox',
#  '/Group',
#  '/MediaBox',
#  '/Parent',
#  '/Resources',
#  '/Rotate',
#  '/StructParents',
#  '/TrimBox',
#  '/Type']

# %%
fortress_of_dib  = pdfReader.getPage(2).extractText()

# %%
pprint(fortress_of_dib)
# Out:
# ('2INTRODUCT\n'
#  'ION\n'
#  'Your GM is ill, but you want to game anyway and volunteer \n'
#  'to run the game. Or perhaps you ran into a last-minute Life \n'
#  'Situation that ate your usual preparation time for your campaign, \n'
#  'and everyone truly needs a break from the ever-present Real \n'
#  'World. Fear not! With the scenarios herein, you can quickly and \n'
#  '\n'
#  'easily take your group of adventurers through an interesting and \n'
#  '\n'
#  'compelling story, defeat some villainous forces, and save the day \n'
#  '\n'
#  '(or perhaps more). For those player characters (PCs) who are \n'
#  '\n'
#  'more pragmatic, yes, there are rewards of varying kinds!\n'
#  'ˆˆ˘\n'
#  '. ˜e door at the back of the wagon is \n'
#  'solidly reinforced. Forcing the door requires a DC 17 Strength \n'
#  '\n'
#  'check. ˜e DC for this check is reduced to 14 if the fortress has \n'
#  '\n'
#  'less than half its hp remaining. Once the door is forced, the \n'
#  '\n'
# ...
